# %%
#Voting eligibility criteria

age = int(input("Enter your age:"))
if(age>=18):
    print("Eligible")
else:
    print("Not Eligible")
# Out:
# Enter your age: 20
# Eligible

# %%
#check for positive or negative or zero 
num = int(input("Enter Number:"))
if(num==0):
    print("Zero")
elif(num>0):
    print("Positive")
else:
    print("Negative")
# Out:
# Enter Number: 10
# Positive

# %%
#gift to the employee based on salary
salary = float(input("Enter salary:"))
if (salary>=100000):
    print("Send gift of 10000")
elif(salary>=50000):
    print("Send gift of 5000")
else:
    print("Send gift of 1000")
# Out:
# Enter salary: 1000000
# Send gift of 10000

# %%
#check for prime number
num=int(input("Enter a number:"))


if num>1:
    for i in range(2,num):
        if (num%i==0):
            print("Not Prime")
            break
    else:
        print("Prime Number")
else:
    print("Enter greater than 1")
# Out:
# Enter a number: 2
# Prime Number

# %%
#swiggy or zomato offer
no_of_orders = int(input("Enter no. of order:"))
if(no_of_orders>=10):
    print("50% Discount")
elif(no_of_orders>=5):
    print("25% Discount")
elif(no_of_orders>=1):
    print("10% Discount")
else:
    print("Placed order to get discount on next order")
# Out:
# Enter no. of order: 5
# 25% Discount

# %%
#login credential
while(True):
    password=input("Enter Password:")
    if(password=="admin"):
        print("Logged in Successfully")
        break
    else:
        print("Wrong Password")
# Out:
# Enter Password: ritik
# Wrong Password
# Enter Password: admin
# Logged in Successfully

# %%
#ATM Machine
Balance=100000
while(True):
    print("Press 1 to Check Balance\nPress 2 to Withdraw money\nPress 3 to Add money\nPress 4 to Exit")
    n = int(input("What you want to do"))
    if n==1:
        print("\tCurrent Balance: ",Balance)
        
    elif n==2:
        a=float(input("Enter Amount to Withdraw:"))
        Balance-=a
        print("\tCollect your money\n\tRemaining Balance",Balance)
        
        
    elif n==3:
        b=float(input("Enter Amount you want to Add"))
        Balance+=a
        print("\tMoney Added\n\tCurrent Balance",Balance)
        
    elif n==4:
        print("Collect your Card")
        break

    else:
        print("\tPress Between 1 to 4")
# Out:
# Press 1 to Check Balance
# Press 2 to Withdraw money
# Press 3 to Add money
# Press 4 to Exit
# What you want to do 1
# 	Current Balance:  100000
# Press 1 to Check Balance
# Press 2 to Withdraw money
# Press 3 to Add money
# Press 4 to Exit
# What you want to do 2
# Enter Amount to Withdraw: 100
# 	Collect your money
# 	Remaining Balance 99900.0
# Press 1 to Check Balance
# Press 2 to Withdraw money
# Press 3 to Add money
# Press 4 to Exit
# What you want to do 3
# Enter Amount you want to Add 100
# 	Money Added
# 	Current Balance 100000.0
# Press 1 to Check Balance
# Press 2 to Withdraw money
# Press 3 to Add money
# Press 4 to Exit
# What you want to do 4
